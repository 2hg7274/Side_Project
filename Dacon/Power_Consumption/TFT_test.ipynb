# %% [markdown]
# # Demnad forecasting with the Temporal Fusion Transformer
# [Example](https://pytorch-forecasting.readthedocs.io/en/latest/tutorials/stallion.html#Load-data)

# %%
import os
import warnings

warnings.filterwarnings("ignore")  # avoid printing out absolute paths

import copy
from pathlib import Path
import warnings

import lightning.pytorch as pl
from lightning.pytorch.callbacks import EarlyStopping, LearningRateMonitor
from lightning.pytorch.loggers import TensorBoardLogger
import numpy as np
import pandas as pd
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import MAE, SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# %% [markdown]
# # Load data

# %%
from pytorch_forecasting.data.examples import get_stallion_data

data = get_stallion_data()

# add time index
data["time_idx"] = data["date"].dt.year * 12 + data["date"].dt.month
data["time_idx"] -= data["time_idx"].min()

# add additional features
data["month"] = data.date.dt.month.astype(str).astype("category")  # categories have be strings
data["log_volume"] = np.log(data.volume + 1e-8)
data["avg_volume_by_sku"] = data.groupby(["time_idx", "sku"], observed=True).volume.transform("mean")
data["avg_volume_by_agency"] = data.groupby(["time_idx", "agency"], observed=True).volume.transform("mean")

# we want to encode special days as one variable and thus need to first reverse one-hot encoding
special_days = [
    "easter_day",
    "good_friday",
    "new_year",
    "christmas",
    "labor_day",
    "independence_day",
    "revolution_day_memorial",
    "regional_games",
    "fifa_u_17_world_cup",
    "football_gold_cup",
    "beer_capital",
    "music_fest",
]
data[special_days] = data[special_days].apply(lambda x: x.map({0: "-", 1: x.name})).astype("category")
data.sample(10, random_state=521)
# Out:
#           agency     sku     volume       date  industry_volume  soda_volume  \
# 291    Agency_25  SKU_03     0.5076 2013-01-01        492612703    718394219
# 871    Agency_29  SKU_02     8.7480 2015-01-01        498567142    762225057
# 19532  Agency_47  SKU_01     4.9680 2013-09-01        454252482    789624076
# 2089   Agency_53  SKU_07    21.6825 2013-10-01        480693900    791658684
# 9755   Agency_17  SKU_02   960.5520 2015-03-01        515468092    871204688
# 7561   Agency_05  SKU_03  1184.6535 2014-02-01        425528909    734443953
# 19204  Agency_11  SKU_05     5.5593 2017-08-01        623319783   1049868815
# 8781   Agency_48  SKU_04  4275.1605 2013-03-01        509281531    892192092
# 2540   Agency_07  SKU_21     0.0000 2015-10-01        544203593    761469815
# 12084  Agency_21  SKU_03    46.3608 2017-04-01        589969396    940912941
#
#        avg_max_temp  price_regular  price_actual    discount  ...  \
# 291       25.845238    1264.162234   1152.473405  111.688829  ...
# 871       27.584615    1316.098485   1296.804924   19.293561  ...
# 19532     30.665957    1269.250000   1266.490490    2.759510  ...
# 2089      29.197727    1193.842373   1128.124395   65.717978  ...
# 9755      23.608120    1338.334248   1232.128069  106.206179  ...
# 7561      28.668254    1369.556376   1161.135214  208.421162  ...
# 19204     31.915385    1922.486644   1651.307674  271.178970  ...
# 8781      26.767857    1761.258209   1546.059670  215.198539  ...
# 2540      28.987755       0.000000      0.000000    0.000000  ...
# 12084     32.478910    1675.922116   1413.571789  262.350327  ...
#
#        football_gold_cup  beer_capital  music_fest discount_in_percent  \
# 291                    -             -           -            8.835008
# 871                    -             -           -            1.465966
# 19532                  -             -           -            0.217413
# 2089                   -  beer_capital           -            5.504745
# 9755                   -             -  music_fest            7.935699
# 7561                   -             -           -           15.218151
# 19204                  -             -           -           14.105636
# 8781                   -             -  music_fest           12.218455
# 2540                   -             -           -            0.000000
# 12084                  -             -           -           15.654088
#
#       timeseries time_idx month log_volume avg_volume_by_sku  \
# 291          228        0     1  -0.678062       1225.306376
# 871          177       24     1   2.168825       1634.434615
# 19532        322        8     9   1.603017       2625.472644
# 2089         240        9    10   3.076505         38.529107
# 9755         259       26     3   6.867508       2143.677462
# 7561          21       13     2   7.077206       1566.643589
# 19204         17       55     8   1.715472       1385.225478
# 8781         151        2     3   8.360577       1757.950603
# 2540         300       33    10 -18.420681          0.000000
# 12084        181       51     4   3.836454       2034.293024
#
#       avg_volume_by_agency
# 291              99.650400
# 871              11.397086
# 19532            48.295650
# 2089           2511.035175
# 9755            396.022140
# 7561           1881.866367
# 19204           109.699200
# 8781           1925.272108
# 2540           2418.719550
# 12084           109.381800
#
# [10 rows x 31 columns]

# %%
data.describe()
# Out:
#              volume                 date  industry_volume   soda_volume  \
# count  21000.000000                21000     2.100000e+04  2.100000e+04
# mean    1492.403982  2015-06-16 20:48:00     5.439214e+08  8.512000e+08
# min        0.000000  2013-01-01 00:00:00     4.130518e+08  6.964015e+08
# 25%        8.272388  2014-03-24 06:00:00     5.090553e+08  7.890880e+08
# 50%      158.436000  2015-06-16 00:00:00     5.512000e+08  8.649196e+08
# 75%     1774.793475  2016-09-08 12:00:00     5.893715e+08  9.005551e+08
# max    22526.610000  2017-12-01 00:00:00     6.700157e+08  1.049869e+09
# std     2711.496882                  NaN     6.288022e+07  7.824340e+07
#
#        avg_max_temp  price_regular  price_actual      discount  \
# count  21000.000000   21000.000000  21000.000000  21000.000000
# mean      28.612404    1451.536344   1267.347450    184.374146
# min       16.731034       0.000000  -3121.690141      0.000000
# 25%       25.374816    1311.547158   1178.365653     54.935108
# 50%       28.479272    1495.174592   1324.695705    138.307225
# 75%       31.568405    1725.652080   1517.311427    272.298630
# max       45.290476   19166.625000   4925.404000  19166.625000
# std        3.972833     683.362417    587.757323    257.469968
#
#        avg_population_2017  avg_yearly_household_income_2017  \
# count         2.100000e+04                      21000.000000
# mean          1.045065e+06                     151073.494286
# min           1.227100e+04                      90240.000000
# 25%           6.018900e+04                     110057.000000
# 50%           1.232242e+06                     131411.000000
# 75%           1.729177e+06                     206553.000000
# max           3.137874e+06                     247220.000000
# std           9.291926e+05                      50409.593114
#
#        discount_in_percent   timeseries      time_idx    log_volume  \
# count         21000.000000  21000.00000  21000.000000  21000.000000
# mean             10.574884    174.50000     29.500000      2.464118
# min               0.000000      0.00000      0.000000    -18.420681
# 25%               3.749628     87.00000     14.750000      2.112923
# 50%               8.948990    174.50000     29.500000      5.065351
# 75%              15.647058    262.00000     44.250000      7.481439
# max             226.740147    349.00000     59.000000     10.022453
# std               9.590813    101.03829     17.318515      8.178218
#
#        avg_volume_by_sku  avg_volume_by_agency
# count       21000.000000          21000.000000
# mean         1492.403982           1492.403982
# min             0.000000              0.000000
# 25%           932.285496            113.420250
# 50%          1402.305264           1730.529771
# 75%          2195.362302           2595.316500
# max          4332.363750           5884.717375
# std          1051.790829           1328.239698

# %% [markdown]
# # Create dataset and dataloaders

# %%
max_prediction_length = 6
max_encoder_length = 24
training_cutoff = data["time_idx"].max() - max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="volume",
    group_ids=["agency", "sku"],
    min_encoder_length=max_encoder_length // 2,  # keep encoder length long (as it is in the validation set)
    max_encoder_length=max_encoder_length,
    min_prediction_length=1,
    max_prediction_length=max_prediction_length,
    static_categoricals=["agency", "sku"],
    static_reals=["avg_population_2017", "avg_yearly_household_income_2017"],
    time_varying_known_categoricals=["special_days", "month"],
    variable_groups={"special_days": special_days},  # group of categorical variables can be treated as one variable
    time_varying_known_reals=["time_idx", "price_regular", "discount_in_percent"],
    time_varying_unknown_categoricals=[],
    time_varying_unknown_reals=[
        "volume",
        "log_volume",
        "industry_volume",
        "soda_volume",
        "avg_max_temp",
        "avg_volume_by_agency",
        "avg_volume_by_sku",
    ],
    target_normalizer=GroupNormalizer(
        groups=["agency", "sku"], transformation="softplus"
    ),  # use softplus and normalize by group
    add_relative_time_idx=True,
    add_target_scales=True,
    add_encoder_length=True,
)

# create validation set (predict=True) which means to predict the last max_prediction_length points in time
# for each series
validation = TimeSeriesDataSet.from_dataset(training, data, predict=True, stop_randomization=True)

# create dataloaders for model
batch_size = 128  # set this between 32 to 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size * 10, num_workers=0)

# %% [markdown]
# # Create baseline model

# %%
# calculate baseline mean absolute error, i.e. predict next value as the last available value from the history
baseline_predictions = Baseline().predict(val_dataloader, return_y=True)
MAE()(baseline_predictions.output, baseline_predictions.y)
# Out:
# Missing logger folder: c:\Users\hanhyungu\Desktop\study\Side_Project\Dacon\Power_Consumption\lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# tensor(293.0088, device='cuda:0')

# %% [markdown]
# # Train the Temporal Fusion Transformer

# %% [markdown]
# ## Find optimal learning rate

# %%
# configure network and trainer
pl.seed_everything(42)
trainer = pl.Trainer(
    accelerator="gpu",
    # clipping gradients is a hyperparameter and important to prevent divergance
    # of the gradient for recurrent neural networks
    gradient_clip_val=0.1,
)


tft = TemporalFusionTransformer.from_dataset(
    training,
    # not meaningful for finding the learning rate but otherwise very important
    learning_rate=0.03,
    hidden_size=8,  # most important hyperparameter apart from learning rate
    # number of attention heads. Set to up to 4 for large datasets
    attention_head_size=1,
    dropout=0.1,  # between 0.1 and 0.3 are good values
    hidden_continuous_size=8,  # set to <= hidden_size
    loss=QuantileLoss(),
    optimizer="Ranger"
    # reduce learning rate if no improvement in validation loss after x epochs
    # reduce_on_plateau_patience=1000,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 13.5k

# %%
# find optimal learning rate
from lightning.pytorch.tuner import Tuner

res = Tuner(trainer).lr_find(
    tft,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
    max_lr=10.0,
    min_lr=1e-6,
)

print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Finding best initial lr: 100%|██████████| 100/100 [00:09<00:00, 10.92it/s]`Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:09<00:00, 10.98it/s]
# Learning rate set to 0.041686938347033554
# Restoring states from the checkpoint path at c:\Users\hanhyungu\Desktop\study\Side_Project\Dacon\Power_Consumption\.lr_find_578bf09a-fb99-421b-a902-7ea96881debd.ckpt
# Restored all states from the checkpoint at c:\Users\hanhyungu\Desktop\study\Side_Project\Dacon\Power_Consumption\.lr_find_578bf09a-fb99-421b-a902-7ea96881debd.ckpt
# suggested learning rate: 0.041686938347033554

# %% [markdown]
# # Train model

# %%
# configure network and trainer
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
lr_logger = LearningRateMonitor()  # log the learning rate
logger = TensorBoardLogger("lightning_logs")  # logging results to a tensorboard

trainer = pl.Trainer(
    max_epochs=50,
    accelerator="gpu",
    enable_model_summary=True,
    gradient_clip_val=0.1,
    limit_train_batches=50,  # coment in for training, running valiation every 30 batches
    # fast_dev_run=True,  # comment in to check that networkor dataset has no serious bugs
    callbacks=[lr_logger, early_stop_callback],
    logger=logger,
)

tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=0.03,
    hidden_size=16,
    attention_head_size=2,
    dropout=0.1,
    hidden_continuous_size=8,
    loss=QuantileLoss(),
    log_interval=10,  # uncomment for learning rate finder and otherwise, e.g. to 10 for logging every 10 batches
    optimizer="Ranger",
    reduce_on_plateau_patience=4,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 29.4k

# %%
# fit network
trainer.fit(
    tft,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# Missing logger folder: lightning_logs\lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 1.3 K
# 3  | prescalers                         | ModuleDict                      | 256
# 4  | static_variable_selection          | VariableSelectionNetwork        | 3.4 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 8.0 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 2.7 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 808
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 29.4 K    Trainable params
# 0         Non-trainable params
# 29.4 K    Total params
# 0.118     Total estimated model params size (MB)
# Epoch 17: 100%|██████████| 50/50 [00:06<00:00,  7.90it/s, v_num=0, train_loss_step=98.80, val_loss=153.0, train_loss_epoch=84.80]

# %% [markdown]
# # Hyperparmeter tuning

# %%
import pickle

from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# create study
study = optimize_hyperparameters(
    train_dataloader,
    val_dataloader,
    model_path="optuna_test",
    n_trials=20,
    max_epochs=30,
    gradient_clip_val_range=(0.01, 1.0),
    hidden_size_range=(8, 128),
    hidden_continuous_size_range=(8, 128),
    attention_head_size_range=(1, 4),
    learning_rate_range=(0.001, 0.1),
    dropout_range=(0.1, 0.3),
    trainer_kwargs=dict(limit_train_batches=30),
    reduce_on_plateau_patience=4,
    use_learning_rate_finder=False,  # use Optuna to find ideal learning rate or use in-built learning rate finder
)

# save study results - also we can resume tuning at a later point in time
with open("test_study.pkl", "wb") as fout:
    pickle.dump(study, fout)

# show best hyperparameters
print(study.best_trial.params)
# Out:
# [I 2023-07-20 17:09:35,038] A new study created in memory with name: no-name-33f42e3f-05d7-47da-8e21-d0c502e0916e
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:11:27,025] Trial 0 finished with value: 155.2706298828125 and parameters: {'gradient_clip_val': 0.15455136882547874, 'hidden_size': 15, 'dropout': 0.14746226876361776, 'hidden_continuous_size': 10, 'attention_head_size': 4, 'learning_rate': 0.04040523037270073}. Best is trial 0 with value: 155.2706298828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:12:54,297] Trial 1 finished with value: 159.79095458984375 and parameters: {'gradient_clip_val': 0.09824984080828951, 'hidden_size': 32, 'dropout': 0.2587351785683454, 'hidden_continuous_size': 32, 'attention_head_size': 1, 'learning_rate': 0.026734935680535567}. Best is trial 0 with value: 155.2706298828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:14:41,940] Trial 2 finished with value: 161.11392211914062 and parameters: {'gradient_clip_val': 0.6853955509538593, 'hidden_size': 18, 'dropout': 0.21333995251672166, 'hidden_continuous_size': 14, 'attention_head_size': 1, 'learning_rate': 0.05769856425181271}. Best is trial 0 with value: 155.2706298828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:16:35,040] Trial 3 finished with value: 159.8645782470703 and parameters: {'gradient_clip_val': 0.5019692064868188, 'hidden_size': 56, 'dropout': 0.20574479357468034, 'hidden_continuous_size': 23, 'attention_head_size': 1, 'learning_rate': 0.0019828648033017086}. Best is trial 0 with value: 155.2706298828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:18:25,504] Trial 4 finished with value: 150.7550048828125 and parameters: {'gradient_clip_val': 0.28659332445888136, 'hidden_size': 15, 'dropout': 0.29352297885208567, 'hidden_continuous_size': 13, 'attention_head_size': 4, 'learning_rate': 0.013581900664319174}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:20:11,654] Trial 5 finished with value: 162.66880798339844 and parameters: {'gradient_clip_val': 0.4679344408885187, 'hidden_size': 16, 'dropout': 0.21289018233489537, 'hidden_continuous_size': 15, 'attention_head_size': 1, 'learning_rate': 0.06455230307148951}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:22:07,262] Trial 6 finished with value: 154.5746612548828 and parameters: {'gradient_clip_val': 0.3147174118628125, 'hidden_size': 55, 'dropout': 0.15093796598365505, 'hidden_continuous_size': 14, 'attention_head_size': 1, 'learning_rate': 0.008771057109822247}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:23:36,122] Trial 7 finished with value: 152.32693481445312 and parameters: {'gradient_clip_val': 0.09641303903390622, 'hidden_size': 8, 'dropout': 0.24408455433647472, 'hidden_continuous_size': 8, 'attention_head_size': 3, 'learning_rate': 0.03841028697651676}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:25:25,431] Trial 8 finished with value: 165.3341827392578 and parameters: {'gradient_clip_val': 0.02975956944864181, 'hidden_size': 9, 'dropout': 0.24901681452716087, 'hidden_continuous_size': 8, 'attention_head_size': 3, 'learning_rate': 0.0022249520916805153}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:27:12,643] Trial 9 finished with value: 152.43429565429688 and parameters: {'gradient_clip_val': 0.045108374859071966, 'hidden_size': 19, 'dropout': 0.26365766684668585, 'hidden_continuous_size': 9, 'attention_head_size': 1, 'learning_rate': 0.005895534864732651}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:29:28,040] Trial 10 finished with value: 156.90469360351562 and parameters: {'gradient_clip_val': 0.010629888221558728, 'hidden_size': 125, 'dropout': 0.2930014132594439, 'hidden_continuous_size': 66, 'attention_head_size': 4, 'learning_rate': 0.01298378080993281}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:30:55,399] Trial 11 finished with value: 163.6693115234375 and parameters: {'gradient_clip_val': 0.20197817961241088, 'hidden_size': 8, 'dropout': 0.297595489535837, 'hidden_continuous_size': 8, 'attention_head_size': 3, 'learning_rate': 0.021584515628590477}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:32:23,115] Trial 12 finished with value: 160.09014892578125 and parameters: {'gradient_clip_val': 0.9558028268771216, 'hidden_size': 8, 'dropout': 0.23953332989113857, 'hidden_continuous_size': 8, 'attention_head_size': 3, 'learning_rate': 0.0975912514875726}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:34:10,793] Trial 13 finished with value: 156.1661834716797 and parameters: {'gradient_clip_val': 0.10062642106312047, 'hidden_size': 11, 'dropout': 0.27723275338145154, 'hidden_continuous_size': 8, 'attention_head_size': 4, 'learning_rate': 0.02063247545327106}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:35:54,559] Trial 14 finished with value: 155.0144805908203 and parameters: {'gradient_clip_val': 0.24509064075428177, 'hidden_size': 12, 'dropout': 0.2363352984714257, 'hidden_continuous_size': 9, 'attention_head_size': 2, 'learning_rate': 0.03473607470988173}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:37:41,371] Trial 15 finished with value: 165.29042053222656 and parameters: {'gradient_clip_val': 0.37320444808309816, 'hidden_size': 11, 'dropout': 0.2781616043790274, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.013735152038270134}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:39:30,875] Trial 16 finished with value: 157.64886474609375 and parameters: {'gradient_clip_val': 0.12189295825325834, 'hidden_size': 23, 'dropout': 0.10144996509135075, 'hidden_continuous_size': 11, 'attention_head_size': 4, 'learning_rate': 0.005683702311179861}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:41:19,895] Trial 17 finished with value: 169.21099853515625 and parameters: {'gradient_clip_val': 0.22359208520406113, 'hidden_size': 13, 'dropout': 0.27089943654395293, 'hidden_continuous_size': 9, 'attention_head_size': 3, 'learning_rate': 0.0011159213935611825}. Best is trial 4 with value: 150.7550048828125.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:42:48,306] Trial 18 finished with value: 149.6590118408203 and parameters: {'gradient_clip_val': 0.06864929210691521, 'hidden_size': 8, 'dropout': 0.29627330116194706, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.018000345387089802}. Best is trial 18 with value: 149.6590118408203.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# [I 2023-07-20 17:44:35,103] Trial 19 finished with value: 167.59523010253906 and parameters: {'gradient_clip_val': 0.05932243987397975, 'hidden_size': 10, 'dropout': 0.2957291146051704, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.016240023871992214}. Best is trial 18 with value: 149.6590118408203.
# {'gradient_clip_val': 0.06864929210691521, 'hidden_size': 8, 'dropout': 0.29627330116194706, 'hidden_continuous_size': 8, 'attention_head_size': 2, 'learning_rate': 0.018000345387089802}

# %% [markdown]
# # Evaluate performance

# %%
# load the best model according to the validation loss
# (given that we use early stopping, this is not necessarily the last epoch)
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)

# %%
# calcualte mean absolute error on validation set
predictions = best_tft.predict(val_dataloader, return_y=True, trainer_kwargs=dict(accelerator="cpu"))
MAE()(predictions.output, predictions.y)
# Out:
# tensor(262.1897)

# %%
# raw predictions are a dictionary from which all kind of information including quantiles can be extracted
raw_predictions = best_tft.predict(val_dataloader, mode="raw", return_x=True)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
for idx in range(10):  # plot 10 examples
    best_tft.plot_prediction(raw_predictions.x, raw_predictions.output, idx=idx, add_loss_to_title=True)

# %% [markdown]
# # Worst performers

# %%
# calcualte metric by which to display
predictions = best_tft.predict(val_dataloader, return_y=True)
mean_losses = SMAPE(reduction="none")(predictions.output, predictions.y).mean(1)
indices = mean_losses.argsort(descending=True)  # sort losses
for idx in range(10):  # plot 10 examples
    best_tft.plot_prediction(
        raw_predictions.x,
        raw_predictions.output,
        idx=indices[idx],
        add_loss_to_title=SMAPE(quantiles=best_tft.loss.quantiles),
    )
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# # Actuals vs predictions by vaiables

# %%
predictions = best_tft.predict(val_dataloader, return_x=True)
predictions_vs_actuals = best_tft.calculate_prediction_actual_by_variable(predictions.x, predictions.output)
best_tft.plot_prediction_actual_by_variable(predictions_vs_actuals)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# {'avg_population_2017': <Figure size 1000x500 with 2 Axes>,
#  'avg_yearly_household_income_2017': <Figure size 1000x500 with 2 Axes>,
#  'encoder_length': <Figure size 1000x500 with 2 Axes>,
#  'volume_center': <Figure size 1000x500 with 2 Axes>,
#  'volume_scale': <Figure size 1000x500 with 2 Axes>,
#  'time_idx': <Figure size 1000x500 with 2 Axes>,
#  'price_regular': <Figure size 1000x500 with 2 Axes>,
#  'discount_in_percent': <Figure size 1000x500 with 2 Axes>,
#  'relative_time_idx': <Figure size 1000x500 with 2 Axes>,
#  'volume': <Figure size 1000x500 with 2 Axes>,
#  'log_volume': <Figure size 1000x500 with 2 Axes>,
#  'industry_volume': <Figure size 1000x500 with 2 Axes>,
#  'soda_volume': <Figure size 1000x500 with 2 Axes>,
#  'avg_max_temp': <Figure size 1000x500 with 2 Axes>,
#  'avg_volume_by_agency': <Figure size 1000x500 with 2 Axes>,
#  'avg_volume_by_sku': <Figure size 1000x500 with 2 Axes>,
#  'agency': <Figure size 1000x500 with 2 Axes>,
#  'sku': <Figure size 1000x500 with 2 Axes>,
#  'special_days': <Figure size 1000x500 with 2 Axes>,
#  'month': <Figure size 1000x500 with 2 Axes>}

# %% [markdown]
# # predict on selected data

# %%
best_tft.predict(
    training.filter(lambda x: (x.agency == "Agency_01") & (x.sku == "SKU_01") & (x.time_idx_first_prediction == 15)),
    mode="quantiles",
)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# tensor([[[ 67.2282,  91.5627, 108.4249, 128.7108, 149.2614, 166.8282, 197.6999],
#          [ 50.1163,  74.9274,  92.6163, 112.9813, 134.3998, 159.7795, 189.9850],
#          [ 45.9785,  68.3323,  84.2975, 102.8565, 121.6693, 145.2374, 173.8781],
#          [ 40.3075,  57.9516,  71.7885,  87.9218, 106.6224, 129.4212, 159.2765],
#          [ 46.9937,  65.8602,  79.3658,  96.0037, 114.5141, 133.5044, 158.0665],
#          [ 40.4406,  59.7678,  73.4162,  89.5851, 106.4323, 127.8374, 151.5695]]],
#        device='cuda:0')

# %%
raw_prediction = best_tft.predict(
    training.filter(lambda x: (x.agency == "Agency_01") & (x.sku == "SKU_01") & (x.time_idx_first_prediction == 15)),
    mode="raw",
    return_x=True,
)
best_tft.plot_prediction(raw_prediction.x, raw_prediction.output, idx=0)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# # Predict on new data

# %%
# select last 24 months from data (max_encoder_length is 24)
encoder_data = data[lambda x: x.time_idx > x.time_idx.max() - max_encoder_length]

# select last known data point and create decoder data from it by repeating it and incrementing the month
# in a real world dataset, we should not just forward fill the covariates but specify them to account
# for changes in special days and prices (which you absolutely should do but we are too lazy here)
last_data = data[lambda x: x.time_idx == x.time_idx.max()]
decoder_data = pd.concat(
    [last_data.assign(date=lambda x: x.date + pd.offsets.MonthBegin(i)) for i in range(1, max_prediction_length + 1)],
    ignore_index=True,
)

# add time index consistent with "data"
decoder_data["time_idx"] = decoder_data["date"].dt.year * 12 + decoder_data["date"].dt.month
decoder_data["time_idx"] += encoder_data["time_idx"].max() + 1 - decoder_data["time_idx"].min()

# adjust additional time feature(s)
decoder_data["month"] = decoder_data.date.dt.month.astype(str).astype("category")  # categories have be strings

# combine encoder and decoder data
new_prediction_data = pd.concat([encoder_data, decoder_data], ignore_index=True)

# %%
new_raw_predictions = best_tft.predict(new_prediction_data, mode="raw", return_x=True)

for idx in range(10):  # plot 10 examples
    best_tft.plot_prediction(new_raw_predictions.x, new_raw_predictions.output, idx=idx, show_future_observed=False)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# # Interpret model

# %% [markdown]
# ## Variable importances

# %%
interpretation = best_tft.interpret_output(raw_predictions.output, reduction="sum")
best_tft.plot_interpretation(interpretation)
# Out:
# {'attention': <Figure size 640x480 with 1 Axes>,
#  'static_variables': <Figure size 700x375 with 1 Axes>,
#  'encoder_variables': <Figure size 700x525 with 1 Axes>,
#  'decoder_variables': <Figure size 700x350 with 1 Axes>}

# %% [markdown]
# ## Partial dependency

# %%
dependency = best_tft.predict_dependency(
    val_dataloader.dataset, "discount_in_percent", np.linspace(0, 30, 30), show_progress_bar=True, mode="dataframe"
)
# Out:
# Predict:   0%|          | 0/30 [00:00<?, ? batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:   3%|▎         | 1/30 [00:00<00:15,  1.88 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:   7%|▋         | 2/30 [00:00<00:12,  2.29 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  10%|█         | 3/30 [00:01<00:11,  2.44 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  13%|█▎        | 4/30 [00:01<00:10,  2.57 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  17%|█▋        | 5/30 [00:02<00:09,  2.59 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  20%|██        | 6/30 [00:02<00:09,  2.62 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  23%|██▎       | 7/30 [00:02<00:08,  2.66 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  27%|██▋       | 8/30 [00:03<00:08,  2.65 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  30%|███       | 9/30 [00:03<00:08,  2.60 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  33%|███▎      | 10/30 [00:03<00:07,  2.56 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  37%|███▋      | 11/30 [00:04<00:07,  2.59 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  40%|████      | 12/30 [00:04<00:06,  2.60 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  43%|████▎     | 13/30 [00:05<00:06,  2.63 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  47%|████▋     | 14/30 [00:05<00:06,  2.64 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  50%|█████     | 15/30 [00:05<00:05,  2.61 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  53%|█████▎    | 16/30 [00:06<00:05,  2.56 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  57%|█████▋    | 17/30 [00:06<00:05,  2.57 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  60%|██████    | 18/30 [00:06<00:04,  2.63 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  63%|██████▎   | 19/30 [00:07<00:04,  2.68 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  67%|██████▋   | 20/30 [00:07<00:03,  2.69 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  70%|███████   | 21/30 [00:08<00:03,  2.70 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  73%|███████▎  | 22/30 [00:08<00:03,  2.63 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  77%|███████▋  | 23/30 [00:08<00:02,  2.66 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  80%|████████  | 24/30 [00:09<00:02,  2.63 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  83%|████████▎ | 25/30 [00:09<00:01,  2.61 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  87%|████████▋ | 26/30 [00:10<00:01,  2.58 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  90%|█████████ | 27/30 [00:10<00:01,  2.58 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  93%|█████████▎| 28/30 [00:10<00:00,  2.58 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict:  97%|█████████▋| 29/30 [00:11<00:00,  2.53 batches/s]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predict: 100%|██████████| 30/30 [00:11<00:00,  2.58 batches/s]

# %%
# plotting median and 25% and 75% percentile
agg_dependency = dependency.groupby("discount_in_percent").normalized_prediction.agg(
    median="median", q25=lambda x: x.quantile(0.25), q75=lambda x: x.quantile(0.75)
)
ax = agg_dependency.plot(y="median")
ax.fill_between(agg_dependency.index, agg_dependency.q25, agg_dependency.q75, alpha=0.3)
